# %%
reviews = (spark
    .read
    .json('./data/raw_data/reviews_Musical_Instruments_5.json.gz'))

# %%
reviews.toPandas().head(5)
# Out:
#          asin   helpful  overall  \
# 0  1384719342    [0, 0]      5.0
# 1  1384719342  [13, 14]      5.0
# 2  1384719342    [1, 1]      5.0
# 3  1384719342    [0, 0]      5.0
# 4  1384719342    [0, 0]      5.0
#
#                                           reviewText   reviewTime  \
# 0  Not much to write about here, but it does exac...  02 28, 2014
# 1  The product does exactly as it should and is q...  03 16, 2013
# 2  The primary job of this device is to block the...  08 28, 2013
# 3  Nice windscreen protects my MXL mic and preven...  02 14, 2014
# 4  This pop filter is great. It looks and perform...  02 21, 2014
#
#        reviewerID                                      reviewerName  \
# 0  A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 1  A14VAT5EAX3D9S                                              Jake
# 2  A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3  A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 4   A94QU4C90B1AX                                     SEAN MASLANKA
#
#                                  summary  unixReviewTime
# 0                                   good      1393545600
# 1                                   Jake      1363392000
# 2                   It Does The Job Well      1377648000
# 3          GOOD WINDSCREEN FOR THE MONEY      1392336000
# 4  No more pops when I record my vocals.      1392940800

# %%
product_list = reviews.groupBy('asin').count()
product_list.sort('count', ascending = False).toPandas().head(10)
# Out:
#          asin  count
# 0  B003VWJ2K8    163
# 1  B0002E1G5C    143
# 2  B0002F7K7Y    116
# 3  B003VWKPHC    114
# 4  B0002H0A3S     93
# 5  B0002CZVXM     74
# 6  B0006NDF8A     71
# 7  B0009G1E0K     69
# 8  B0002E2KPC     68
# 9  B0002GLDQM     67

# %%
reviews_per_reviewer = reviews.groupBy('reviewerID').count()

# %%
from pyspark.sql.functions import col, udf, avg
from pyspark.sql.types import DoubleType

usefulness_ratio = udf(
    lambda (useful, out_of): useful / float(out_of + 1), 
    returnType=DoubleType())

usefulness = (reviews
  .select('reviewerID', usefulness_ratio(col('helpful')).alias('usefulness'))
  .groupBy('reviewerID')
  .agg(avg(col('usefulness')).alias('usefulness')))

# %%
rankings = (usefulness
    .join(reviews_per_reviewer, 'reviewerID')
    .select('reviewerID', (col('usefulness') * col('count')).alias('rank'))
    .filter(col('rank') > 1))

# %%
most_reviewed_product = reviews.groupBy('asin').count().sort('count', ascending=False).take(1)[0][0]

best_reviewers = (reviews
   .filter(col('asin') == most_reviewed_product)
   .join(rankings, 'reviewerID')
   .select('asin', 'reviewerID', 'rank', 'summary'))

good_reviews = best_reviewers.filter(col('overall') > 3).sort('rank', ascending=False)

bad_reviews = best_reviewers.filter(col('overall') <= 3).sort('rank', ascending=False)

# %%
bad_reviews.toPandas().head(10)
# Out:
#          asin      reviewerID      rank  \
# 0  B003VWJ2K8   AG3PVU7DCXZTK  3.900000
# 1  B003VWJ2K8  A3IRXJOT9PY6SE  3.437229
# 2  B003VWJ2K8  A15TYOEWBQYF0X  3.333333
# 3  B003VWJ2K8   AYTKUTAP0VA53  1.833333
# 4  B003VWJ2K8   A2RVY2GDMZHH4  1.500000
#
#                                              summary
# 0  Excellent tuner, some issues with the ball joi...
# 1  Two were dead after 3 days, third times the ch...
# 2  I have another brand that works so much easier...
# 3                                        Broken head
# 4                    Works great if it doesn't break

# %%
meta.toPandas().head(10)
# Out:
#   _corrupt_record        asin brand  \
# 0            None  0006428320  None
# 1            None  0014072149
# 2            None  0041291905  None
# 3            None  0041913574  None
# 4            None  0201891859  None
# 5            None  0577088726  None
# 6            None  0634029363  None
# 7            None  0634029355  None
# 8            None  0634029347  None
# 9            None  0634029231  None
#
#                                           categories  \
# 0  [[Musical Instruments, Instrument Accessories,...
# 1                            [[Musical Instruments]]
# 2  [[Musical Instruments, Instrument Accessories,...
# 3                            [[Musical Instruments]]
# 4  [[Musical Instruments, Instrument Accessories,...
# 5  [[Musical Instruments, Instrument Accessories,...
# 6  [[CDs & Vinyl, Special Interest, Instructional...
# 7  [[CDs & Vinyl, Special Interest, Instructional...
# 8  [[CDs & Vinyl, Special Interest, Instructional...
# 9  [[Movies & TV, Movies], [Musical Instruments, ...
#
#                                          description  \
# 0                                               None
# 1  Composer: J.S. Bach.Peters Edition.For two vio...
# 2  Vivaldi's famous set of four violin concertos ...
# 3  444 pages. \nReprint of corrected and revised ...
# 4                                               None
# 5  Sisyphus Redux for solo alto flute, , Ferneyho...
# 6  Learn to play eight of Clapton's best acoustic...
# 7  Learn the riffs and solos of Eric Clapton's ea...
# 8  Riffs and solos from 8 classic Clapton songs, ...
# 9                                               None
#
#                                                imUrl  price  \
# 0  http://ecx.images-amazon.com/images/I/41EpRmh8...  17.95
# 1  http://ecx.images-amazon.com/images/I/41m6ygCq...  18.77
# 2  http://ecx.images-amazon.com/images/I/41maAqSO...    NaN
# 3  http://ecx.images-amazon.com/images/I/513kRMv%...  49.99
# 4  http://ecx.images-amazon.com/images/I/41SXCAzs...    NaN
# 5  http://g-ecx.images-amazon.com/images/G/01/x-s...    NaN
# 6  http://ecx.images-amazon.com/images/I/51TA56RV...  18.99
# 7  http://ecx.images-amazon.com/images/I/51XTMRTM...  13.48
# 8  http://ecx.images-amazon.com/images/I/51N2Q8Z4...  16.19
# 9  http://ecx.images-amazon.com/images/I/51FXTXCW...    NaN
#
#                                              related  \
# 0                                               None
# 1           (None, [B0058DK7RA], None, [B0058DK7RA])
# 2                                               None
# 3                                               None
# 4                                               None
# 5                                               None
# 6  ([0634029355, 0634029347, 0793520843, 63044989...
# 7  ([0634029347, 0634029363, B00C5JH890, B0057CON...
# 8  ([0634029355, 0634029363, B008FIPNQK, B002DGEG...
# 9                                               None
#
#                                            salesRank  \
# 0  (None, None, None, None, None, None, None, Non...
# 1  (None, None, None, None, None, None, None, Non...
# 2  (None, None, None, None, None, None, None, Non...
# 3                                               None
# 4  (None, None, None, None, None, None, None, Non...
# 5                                               None
# 6  (None, None, None, None, None, None, None, Non...
# 7  (None, None, None, None, None, None, None, Non...
# 8  (None, None, None, None, None, None, None, Non...
# 9  (None, None, None, None, None, None, None, Non...
#
#                                                title
# 0  Six Sonatas For Two Flutes Or Violins, Volume ...
# 1  Double Concerto in D Minor By Johann Sebastian...
# 2  Hal Leonard Vivaldi Four Seasons for Piano (Or...
# 3  Aida: Opera in Quattro Atti, Partitura -- Aida...
# 4                                          Nocturnes
# 5                 Sisyphus Redux for solo alto flute
# 6  Hal Leonard Eric Clapton - Acoustic Classics (...
# 7   Hal Leonard Eric Clapton - The Early Years (DVD)
# 8      Hal Leonard Eric Clapton - The Solo Years DVD
# 9  Best of Stevie Ray Vaughan Signature Licks Gui...

# %%
# find out other products these reviews also reviewed

meta = reviews = (spark
    .read
    .json('./data/metadata/meta_Musical_Instruments.json.gz')
    .filter('categories is not null'))

# %%
meta_with_related = meta.filter('related is not null')

# %%
from pyspark.sql.functions import udf, col

last = udf(lambda categories: categories[0][-1])

product_to_category = meta.select('asin', last(col('categories')).alias('category'))

# %%
product_to_category.filter('asin = "0006428320"').show()
# Out:
# +----------+-------------------+
# |      asin|           category|
# +----------+-------------------+
# |0006428320|Sheet Music Folders|
# +----------+-------------------+

# %%
sheet_music_folders = (product_to_category
 .sort('category', acending=False)
 .limit(90000)
#  .filter(col('category') == 'Sheet Music Folders')
)
sheet_music_folders.count()
# Out:
# 84892

# %%
saddles = product_to_category.sort('category', ascending=False).limit(90000).filter('category = "Saddles"').select('asin')

# %%
reviews.join(saddles, reviews.asin == saddles.asin).count()
# Out:
# 24

# %%
reviews.groupBy('reviewerID').count().sort('count', ascending= False).show()
# Out:
# +--------------+-----+
# |    reviewerID|count|
# +--------------+-----+
# | ADH0O8UVJOT10|   42|
# |A1L7M2JXN4EZCR|   38|
# |A15TYOEWBQYF0X|   38|
# |A2EZWZ8MBEDOLN|   36|
# |A2NYK9KWFMJV4Y|   34|
# |A1MVH1WLYDHZ49|   32|
# |A1SD1C8XK3Z3V1|   32|
# |A1GMWTGXW682GB|   29|
# |A34O0KQV4QXWNQ|   28|
# |A1LQC225SE8UNI|   27|
# |A22Z554ZQ8NFPC|   25|
# | AJK15Q9JOEHRH|   25|
# |A1DVUFG2QSJ6IK|   24|
# |A3M1PLEYNDEYO8|   24|
# | AKYDGCKCY7H9F|   23|
# | A2F92AOWTIUIB|   23|
# | A781ITP3HE2N5|   22|
# |A3UXW18DP4WSD6|   21|
# |A1YP96MT6W9FTB|   21|
# |A3ITN3125FJETP|   21|
# +--------------+-----+
# only showing top 20 rows

# %%
reviews.select('asin').distinct().count()
# Out:
# 900

# %%
print(meta.select('asin').distinct().count())
print(reviews.count())
# Out:
# 84892
# 10261

# %%
products = reviews.select(col('asin').alias('asin2')).distinct()
refined_dictionary = (products 
 .join(sheet_music_folders, products.asin2 == sheet_music_folders.asin)
 .select('asin', 'category'))

# %%
refined_dictionary.show()
# Out:
# +----------+--------------------+
# |      asin|            category|
# +----------+--------------------+
# |B000MWWT6E|Distortion & Over...|
# |B000P5NXWM|             Saddles|
# |B000RNB720|Guitar & Bass Acc...|
# |B002R2IUEW|               Picks|
# |B002T45X1G|Condenser Microph...|
# |B005MR6IHK|              Tuning|
# |B0002D0Q2W|        Equalization|
# |B00267OCTA|Multiple-Guitar S...|
# |B004U1QDL0|Chorus, Flange & ...|
# |B0002CZUUG|          Solid Body|
# |B001SC4I16|            Ukuleles|
# |B009MBT68U|  Sheet Music Stands|
# |B0002D02IU|Steel-string Acou...|
# |B0002E1O3G|Electric Guitar S...|
# |B0002E1O90|Acoustic Guitar S...|
# |B001E3SFKO|Windsreens & Pop ...|
# |B002IC1D5E|Electric Guitar S...|
# |B003BFYDBS|              Straps|
# |B004PFWYL4|Electric Guitar B...|
# |B000AC6DVS|Guitar & Bass Acc...|
# +----------+--------------------+
# only showing top 20 rows

# %%
meta.select('asin', col('related'))

# %%
products_in_same_subcategory = meta.select('asin', same_category(col('related'), col('asin')))
# Out:
# +---------------+----------+-----+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+
# |_corrupt_record|      asin|brand|          categories|         description|               imUrl|price|             related|           salesRank|               title|
# +---------------+----------+-----+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+
# |           null|0006428320| null|[WrappedArray(Mus...|                null|http://ecx.images...|17.95|                null|[null,null,null,n...|Six Sonatas For T...|
# |           null|0014072149|     |[WrappedArray(Mus...|Composer: J.S. Ba...|http://ecx.images...|18.77|[null,WrappedArra...|[null,null,null,n...|Double Concerto i...|
# |           null|0041291905| null|[WrappedArray(Mus...|Vivaldi's famous ...|http://ecx.images...| null|                null|[null,null,null,n...|Hal Leonard Vival...|
# +---------------+----------+-----+--------------------+--------------------+--------------------+-----+--------------------+--------------------+--------------------+
# only showing top 3 rows

# %%
# find related products from meta data

related_reviews = (meta
   .filter(col('asin') == 'B0002E1G5C')
   .select('related'))
related_reviews.show(truncate = False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |related                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[WrappedArray(B000OR2RNM, B0002OOMU8, B000788VPG, B0002OOMW6, B000EEJ91I, B0002M6CVC, B0002M6CW6, B001PGXHXA, B0002GJ6FC, B000A6ASSS, B00IFHCOUO, B0002D0CA8, B0002D0CAI, B0002E1O2C, B0002D0CEO, B004XNK7AI, B0002E1H9W, B0002GYW4C, B002HFIEQI, B0018TIADQ, B0055V7UR0, B0002M6B2M, B000EEL6J6, B0002E1O2M, B0002D0COE, B003HNY1IY, B00646MZHK, B000A6GY1I, B00BL6JDUA, B0009G1E0K, B000EELB8W, B0002GLDQM, B0002DUQ04, B007BY2F7O, B0002E3CJ0, B004WFXM8Q, B0039HBNMA, B000RXPN02, B0002CZVWI, B0002E2S90, B00DSSOVJW, B00BL6IYW8, B0002H0JZC, B00GOIC1S6, B0010SHU18, B0002D0E92, B0002GZTT4, B0002D0CQC, B000OR88JE, B00B5LCADS, B006X0UCKY, B000A2HOB6, B001FSZR4U, B0002F58TG, 0634065408, B000OR4W3K, 0634000284, B0013PVWCQ, B00IZCSX9U, B003DVGVIS, B0002E1O5E, B005XOE7OI, B0002DV6RQ, B000A6EUSW, B0078YFA1A, B001I1PWTY, B003986L1W, B0041T53KI, B003B01QSG, B000OR4VOU, B0002D0CH6, B0002D0CGW, B005MR6IHK, B00BKXN9LS, B005J2PXV0, B004N0MKN8, B0002DV7ZM, B009MIBIWK, B0002D0C1C, B007YWHIP2, B005FKF1PY, B000EEHCUS, B000068NW5, B001677QO4, B0002PBS6S, B0007GGUGA, B0002GLCRC, B006X0UE48, B003B0CH5C, B0002GZQEM, B003VWKPHC, B000EEL50Q, B0002E2XOA, B00A716FB0, B0037MA69I, B00074WFO8, B00F20MIC6, B0002E1O3G, B000EEHDM0, B0002PBS6I),null,WrappedArray(B000OR2RNM, B000788VPG),WrappedArray(B000788VPG, B001PGXHXA, B0002OOMU8, B004XNK7AI)]|
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# extract the category of the products

categories = (meta
   .filter(col('asin') == 'B0002E1G5C')
   .select('categories'))
categories.show(truncate = False)
# Out:
# +------------------------------------------------------------------------------------------------------+
# |categories                                                                                            |
# +------------------------------------------------------------------------------------------------------+
# |[WrappedArray(Musical Instruments, Instrument Accessories, Guitar & Bass Accessories, String Winders)]|
# +------------------------------------------------------------------------------------------------------+

# %%
# building a full recommender system

seed = 1800009193L
(split_60_df, split_a_20_df, split_b_20_df) = reviews.randomSplit([6.0, 2.0, 2.0], seed)

training_df = split_60_df.cache()
validation_df = split_a_20_df.cache()
test_df = split_b_20_df.cache()

print('Training: {0}, validation: {1}, test: {2}\n'.format(
  training_df.count(), validation_df.count(), test_df.count())
)
training_df.show(3)
validation_df.show(3)
test_df.show(3)
# Out:
# Training: 6151, validation: 2048, test: 2062
#
# +----------+-------+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------+
# |      asin|helpful|overall|          reviewText| reviewTime|    reviewerID|        reviewerName|             summary|unixReviewTime|
# +----------+-------+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------+
# |1384719342| [0, 0]|    5.0|Nice windscreen p...|02 14, 2014|A2C00NNG1ZQQG2|RustyBill "Sunday...|GOOD WINDSCREEN F...|    1392336000|
# |1384719342| [0, 0]|    5.0|Not much to write...|02 28, 2014|A2IBPI20UZIR0U|cassandra tu "Yea...|                good|    1393545600|
# |1384719342| [1, 1]|    5.0|The primary job o...|08 28, 2013|A195EZSQDW3E21|Rick Bennette "Ri...|It Does The Job Well|    1377648000|
# +----------+-------+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------+
# only showing top 3 rows
#
# +----------+-------+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------+
# |      asin|helpful|overall|          reviewText| reviewTime|    reviewerID|        reviewerName|             summary|unixReviewTime|
# +----------+-------+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------+
# |1384719342| [0, 0]|    5.0|This pop filter i...|02 21, 2014| A94QU4C90B1AX|       SEAN MASLANKA|No more pops when...|    1392940800|
# |B00004Y2UT| [0, 0]|    5.0|Perfect for my Ep...| 07 6, 2008|A3M1PLEYNDEYO8|     G. Thomas "Tom"|         Great cable|    1215302400|
# |B00004Y2UT| [6, 6]|    5.0|Monster makes a w...|04 19, 2012|A2NYK9KWFMJV4Y|Mike Tarrani "Jaz...|One of the best i...|    1334793600|
# +----------+-------+-------+--------------------+-----------+--------------+--------------------+--------------------+--------------+
# only showing top 3 rows
#
# +----------+-------+-------+--------------------+-----------+--------------+-----------------+--------------------+--------------+
# |      asin|helpful|overall|          reviewText| reviewTime|    reviewerID|     reviewerName|             summary|unixReviewTime|
# +----------+-------+-------+--------------------+-----------+--------------+-----------------+--------------------+--------------+
# |B00004Y2UT| [0, 0]|    3.0|I now use this ca...|11 16, 2012| AJNFQI3YR6XJ5|Fender Guy "Rick"|Didn't fit my 199...|    1353024000|
# |B00004Y2UT| [0, 0]|    5.0|I have used monst...|01 19, 2014|A1UPZM995ZAH90|            Brian|Monster Standard ...|    1390089600|
# |B00005ML71| [0, 0]|    3.0|If you are not us...|11 17, 2013|A2NIT6BKW11XJQ|              Jai|HAS TO GET USE TO...|    1384646400|
# +----------+-------+-------+--------------------+-----------+--------------+-----------------+--------------------+--------------+
# only showing top 3 rows

# %%
reviews.printSchema()
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- overall: double (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- reviewTime: string (nullable = true)
#  |-- reviewerID: string (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- unixReviewTime: long (nullable = true)

# %%
# convert reveiwerID from string to int

reviewer_list = reviews.groupBy('reviewerID').count()
reviewer_list.sort('count', ascending = False).toPandas().head(10)

from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(inputCol="reviewerID", outputCol="reviewerIndex")
indexed = indexer.fit(reviews).transform(reviews)

indexer2 = StringIndexer(inputCol="asin", outputCol="asinIndex")
indexed = indexer2.fit(indexed).transform(indexed)

indexed.toPandas()
# Out:
#              asin   helpful  overall  \
# 0      1384719342    [0, 0]      5.0
# 1      1384719342  [13, 14]      5.0
# 2      1384719342    [1, 1]      5.0
# 3      1384719342    [0, 0]      5.0
# 4      1384719342    [0, 0]      5.0
# 5      B00004Y2UT    [0, 0]      5.0
# 6      B00004Y2UT    [0, 0]      5.0
# 7      B00004Y2UT    [0, 0]      3.0
# 8      B00004Y2UT    [0, 0]      5.0
# 9      B00004Y2UT    [0, 0]      5.0
# 10     B00004Y2UT    [6, 6]      5.0
# 11     B00005ML71    [0, 0]      4.0
# 12     B00005ML71    [0, 0]      3.0
# 13     B00005ML71    [0, 0]      5.0
# 14     B00005ML71    [0, 0]      5.0
# 15     B00005ML71    [0, 0]      2.0
# 16     B000068NSX    [0, 0]      4.0
# 17     B000068NSX    [0, 0]      5.0
# 18     B000068NSX    [3, 3]      5.0
# 19     B000068NSX    [0, 0]      5.0
# 20     B000068NSX    [0, 0]      4.0
# 21     B000068NSX    [0, 0]      5.0
# 22     B000068NSX    [0, 0]      4.0
# 23     B000068NTU    [0, 0]      5.0
# 24     B000068NTU    [0, 0]      5.0
# 25     B000068NTU    [0, 0]      4.0
# 26     B000068NTU    [0, 0]      5.0
# 27     B000068NTU    [0, 0]      5.0
# 28     B000068NVI    [1, 1]      4.0
# 29     B000068NVI    [0, 0]      5.0
# ...           ...       ...      ...
# 10231  B00IZCSW3M    [1, 1]      5.0
# 10232  B00IZCSW3M    [0, 0]      5.0
# 10233  B00IZCSW3M    [7, 7]      5.0
# 10234  B00IZCSW3M    [1, 1]      5.0
# 10235  B00IZCSW3M    [1, 2]      5.0
# 10236  B00IZCSW3M    [0, 0]      5.0
# 10237  B00IZCSW3M   [8, 10]      3.0
# 10238  B00IZCSW3M    [0, 0]      5.0
# 10239  B00IZCSW3M    [2, 2]      5.0
# 10240  B00J4TBMVO    [0, 0]      5.0
# 10241  B00J4TBMVO    [0, 0]      5.0
# 10242  B00J4TBMVO    [0, 0]      5.0
# 10243  B00J4TBMVO    [0, 0]      5.0
# 10244  B00J4TBMVO    [0, 0]      5.0
# 10245  B00J4TBMVO    [0, 0]      4.0
# 10246  B00J4TBMVO    [0, 0]      5.0
# 10247  B00J4TBMVO    [2, 2]      2.0
# 10248  B00JBIVXGC    [0, 0]      5.0
# 10249  B00JBIVXGC    [0, 0]      5.0
# 10250  B00JBIVXGC    [0, 0]      5.0
# 10251  B00JBIVXGC    [0, 0]      5.0
# 10252  B00JBIVXGC    [0, 0]      5.0
# 10253  B00JBIVXGC    [0, 0]      4.0
# 10254  B00JBIVXGC    [0, 0]      5.0
# 10255  B00JBIVXGC    [0, 0]      3.0
# 10256  B00JBIVXGC    [0, 0]      5.0
# 10257  B00JBIVXGC    [0, 0]      5.0
# 10258  B00JBIVXGC    [0, 0]      4.0
# 10259  B00JBIVXGC    [0, 0]      4.0
# 10260  B00JBIVXGC    [0, 0]      4.0
#
#                                               reviewText   reviewTime  \
# 0      Not much to write about here, but it does exac...  02 28, 2014
# 1      The product does exactly as it should and is q...  03 16, 2013
# 2      The primary job of this device is to block the...  08 28, 2013
# 3      Nice windscreen protects my MXL mic and preven...  02 14, 2014
# 4      This pop filter is great. It looks and perform...  02 21, 2014
# 5      So good that I bought another one.  Love the h...  12 21, 2012
# 6      I have used monster cables for years, and with...  01 19, 2014
# 7      I now use this cable to run from the output of...  11 16, 2012
# 8      Perfect for my Epiphone Sheraton II.  Monster ...   07 6, 2008
# 9      Monster makes the best cables and a lifetime w...   01 8, 2014
# 10     Monster makes a wide array of cables, includin...  04 19, 2012
# 11     I got it to have it if I needed it. I have fou...  04 22, 2014
# 12     If you are not use to using a large sustaining...  11 17, 2013
# 13     I love it, I used this for my Yamaha ypt-230 a...  06 16, 2013
# 14     I bought this to use in my home studio to cont...  12 31, 2012
# 15     I bought this to use with my keyboard. I wasn'...  08 17, 2013
# 16     This Fender cable is the perfect length for me...  08 13, 2013
# 17     wanted it just on looks alone...It is a nice l...   07 9, 2013
# 18     I've been using these cables for more than 4 m...  03 18, 2013
# 19     Fender cords look great and work just as well....   08 7, 2013
# 20     This is a cool looking cheap cable which works...  03 16, 2012
# 21     The Fender 18 Feet California Clear Instrument...  01 29, 2014
# 22     Very good cable. Well made and it looks great ...   12 8, 2012
# 23     Got this cable to run a rockband keyboard cont...   07 5, 2012
# 24     When I was searching for MIDI cables for my AR...  10 31, 2013
# 25     Cant go wrong. Great quality on a budget price...   07 3, 2013
# 26     The ends of the midi cable look and feel like ...  01 25, 2012
# 27     Just trying to find a midi to midi was a task,...  10 15, 2013
# 28     The Hosa XLR cables are affordable and very he...  07 11, 2012
# 29     I bought these to go from my board to the amp....  02 19, 2014
# ...                                                  ...          ...
# 10231  For a long time, I never thought much about gu...   05 1, 2014
# 10232  My father is a full-time gigging musician prim...  06 14, 2014
# 10233  D'Addario has always been one of the best stri...  05 22, 2014
# 10234  I usually use Gibson Vintage Nickle Strings on...  05 11, 2014
# 10242          130.0      452.0
# 10243           12.0      452.0
# 10244         1167.0      452.0
# 10245          189.0      452.0
# 10246         1407.0      452.0
# 10247          739.0      452.0
# 10248          471.0      192.0
# 10249         1215.0      192.0
# 10250          130.0      192.0
# 10251           12.0      192.0
# 10252            6.0      192.0
# 10253         1287.0      192.0
# 10254          700.0      192.0
# 10255          189.0      192.0
# 10256         1121.0      192.0
# 10257           48.0      192.0
# 10258          740.0      192.0
# 10259          147.0      192.0
# 10260          735.0      192.0
#
# [10261 rows x 11 columns]

# %%
seed = 1800009193L
(split_60_df, split_a_20_df, split_b_20_df) = indexed.randomSplit([6.0, 2.0, 2.0], seed)

training_df = split_60_df.cache()
validation_df = split_a_20_df.cache()
test_df = split_b_20_df.cache()

print('Training: {0}, validation: {1}, test: {2}\n'.format(
  training_df.count(), validation_df.count(), test_df.count())
)
training_df.toPandas()
# Out:
# Training: 6151, validation: 2048, test: 2062
#             asin   helpful  overall  \
# 0     1384719342    [0, 0]      5.0
# 1     1384719342    [0, 0]      5.0
# 2     1384719342    [1, 1]      5.0
# 3     1384719342  [13, 14]      5.0
# 4     B00004Y2UT    [0, 0]      5.0
# 5     B00004Y2UT    [0, 0]      5.0
# 6     B00005ML71    [0, 0]      4.0
# 7     B00005ML71    [0, 0]      5.0
# 8     B00005ML71    [0, 0]      5.0
# 9     B000068NSX    [0, 0]      4.0
# 10    B000068NSX    [0, 0]      4.0
# 11    B000068NSX    [0, 0]      4.0
# 12    B000068NSX    [0, 0]      5.0
# 13    B000068NTU    [0, 0]      5.0
# 14    B000068NTU    [0, 0]      5.0
# 15    B000068NTU    [0, 0]      5.0
# 16    B000068NVI    [0, 0]      4.0
# 17    B000068NVI    [0, 0]      4.0
# 18    B000068NVI    [0, 0]      4.0
# 19    B000068NVI    [0, 0]      4.0
# 20    B000068NVI    [0, 0]      5.0
# 21    B000068NVI    [0, 0]      5.0
# 22    B000068NVI    [0, 0]      5.0
# 23    B000068NW5    [0, 0]      1.0
# 24    B000068NW5    [0, 0]      1.0
# 25    B000068NW5    [0, 0]      3.0
# 26    B000068NW5    [0, 0]      4.0
# 27    B000068NW5    [0, 0]      4.0
# 28    B000068NW5    [0, 0]      4.0
# 29    B000068NW5    [0, 0]      4.0
# ...          ...       ...      ...
# 6121  B00HFRXACG    [2, 2]      5.0
# 6122  B00HFRXACG    [2, 2]      5.0
# 6123  B00IZCSW3M    [0, 0]      5.0
# 6124  B00IZCSW3M    [0, 0]      5.0
# 6125  B00IZCSW3M    [0, 0]      5.0
# 6126  B00IZCSW3M    [0, 0]      5.0
# 6127  B00IZCSW3M    [0, 0]      5.0
# 6128  B00IZCSW3M    [1, 1]      4.0
# 6129  B00IZCSW3M    [1, 1]      4.0
# 6130  B00IZCSW3M    [1, 1]      5.0
# 6131  B00IZCSW3M    [1, 1]      5.0
# 6132  B00IZCSW3M    [1, 1]      5.0
# 6133  B00IZCSW3M    [2, 2]      5.0
# 6134  B00IZCSW3M    [2, 2]      5.0
# 6135  B00IZCSW3M    [4, 4]      5.0
# 6136  B00IZCSW3M   [8, 10]      3.0
# 6137  B00J4TBMVO    [0, 0]      5.0
# 6138  B00J4TBMVO    [0, 0]      5.0
# 6139  B00J4TBMVO    [0, 0]      5.0
# 6140  B00J4TBMVO    [0, 0]      5.0
# 6141  B00J4TBMVO    [2, 2]      2.0
# 6142  B00JBIVXGC    [0, 0]      4.0
# 6143  B00JBIVXGC    [0, 0]      4.0
# 6144  B00JBIVXGC    [0, 0]      5.0
# 6145  B00JBIVXGC    [0, 0]      5.0
# 6146  B00JBIVXGC    [0, 0]      5.0
# 6147  B00JBIVXGC    [0, 0]      5.0
# 6148  B00JBIVXGC    [0, 0]      5.0
# 6149  B00JBIVXGC    [0, 0]      5.0
# 6150  B00JBIVXGC    [0, 0]      5.0
#
#                                              reviewText   reviewTime  \
# 0     Nice windscreen protects my MXL mic and preven...  02 14, 2014
# 1     Not much to write about here, but it does exac...  02 28, 2014
# 2     The primary job of this device is to block the...  08 28, 2013
# 3     The product does exactly as it should and is q...  03 16, 2013
# 4     Monster makes the best cables and a lifetime w...   01 8, 2014
# 5     So good that I bought another one.  Love the h...  12 21, 2012
# 6     I got it to have it if I needed it. I have fou...  04 22, 2014
# 7     I bought this to use in my home studio to cont...  12 31, 2012
# 8     I love it, I used this for my Yamaha ypt-230 a...  06 16, 2013
# 9     This Fender cable is the perfect length for me...  08 13, 2013
# 10    This is a cool looking cheap cable which works...  03 16, 2012
# 11    Very good cable. Well made and it looks great ...   12 8, 2012
# 12    wanted it just on looks alone...It is a nice l...   07 9, 2013
# 13    Got this cable to run a rockband keyboard cont...   07 5, 2012
# 14    Just trying to find a midi to midi was a task,...  10 15, 2013
# 15    The ends of the midi cable look and feel like ...  01 25, 2012
# 16    Hosa products are a good bang for the buck. I ...  03 11, 2014
# 17    I bought this cord after returning a cheap one...  12 14, 2012
# 18    These are not the greatest but they're cheap a...  09 16, 2013
# 19    This is a fine cable at a decent price point, ...  12 15, 2013
# 20    I bought these to go from my board to the amp....  02 19, 2014
# 21    This was exactly what I was after. I have a vo...  09 16, 2013
# 22    Use it every week at gigs.  Solid, no problems...  08 10, 2013
# 23    I'm a pro-cheapo and I hated this thing. They'...  03 14, 2014
# 24    It hums, crackles, and I think I'm having prob...   02 9, 2014
# 25    Works for practice ... it's a guitar instrumen...   07 5, 2014
# 26    Good product at a good price. Have used it mul...  01 25, 2013
# 27    I am not hard on cables.  I typically just plu...   06 8, 2013
# 28    Only complaint is the size which is my fault. ...  06 28, 2014
# 29    This is a very nice cable for the price. I alr...   01 6, 2014
# ...                                                 ...          ...
# 6121  I installed these on a Fender Jazz bass with a...  06 17, 2014
# 6122  I've been using D' Addario strings for 20+ yea...  06 19, 2014
# 6123  I'm a long time D'Addario user. From the time ...   07 7, 2014
# 6124  I've been stringing my guitars with D'Addario ...  05 25, 2014
# 6125  I've used D'Addario strings for years and they...  06 19, 2014
# 6126  Likes:- Pretty smooth.  Minimal fret noise and...  06 19, 2014
# 6127  My father is a full-time gigging musician prim...  06 14, 2014
# 6128  I usually don't use anything lighter than 10s ...   05 9, 2014
# 6129  My daughter is learning how to play and the .1...  05 15, 2014
# 6130  Great strings with a good feel to them. They a...  05 14, 2014
# 6131  I normally get Elixir strings, but these sound...  05 15, 2014
# 6132  I usually use Gibson Vintage Nickle Strings on...  05 11, 2014
# 6133  D'Addario's NYXL1046 Nickel Plated Electric Gu...  06 17, 2014
# 6134  Put these on my G&L; S500 electric. Sound grea...  05 25, 2014
# 6135  I am,  primarily, an acoustic guitar player wh...   06 4, 2014
# 6136  Don't get me wrong, the improvement over the o...  04 28, 2014
# 6137  I can't speak on the claim for a longer string...  07 12, 2014
# 6138  I had the opportunity to try a set of Elixir N...  07 19, 2014
# 6139  I had used Elixer strings for several years on...  07 10, 2014
# 6140  Just put these on my Martin DCX1E and they sou...  07 11, 2014
# 6141  I was looking forward to trying these, as I've...  06 24, 2014
# 6142  I have tried coated strings in the past ( incl...  07 22, 2014
# 6143  Well, MADE by Elixir and DEVELOPED with Taylor...   07 1, 2014
# 6144            Great, just as expected.  Thank to all.  07 20, 2014
# 6145  I had used Elixer strings for several years on...  07 10, 2014
# 6146  I ordered this for my husband, the musician.  ...  06 22, 2014
# 6147  I put these strings on my Guild acoustic elect...  07 11, 2014
# 6148  I really like these strings.  While they are n...   07 4, 2014
# 6149  I've used Elixirs for about five years now. Th...  06 30, 2014
# 6150  True to phosphor bronze these strings have a m...   07 1, 2014
#
#           reviewerID                                      reviewerName  \
# 0     A2C00NNG1ZQQG2                         RustyBill "Sunday Rocker"
# 1     A2IBPI20UZIR0U  cassandra tu "Yeah, well, that's just like, u...
# 2     A195EZSQDW3E21                     Rick Bennette "Rick Bennette"
# 3     A14VAT5EAX3D9S                                              Jake
# 4      AMNTZU1YQN1TH                                       Kurt Robair
# 5     A2A039TZMZHH9Y                               Bill Lewey "blewey"
# 6     A35QFQI0M46LWO                                     Christopher C
# 7     A17SLR18TUMULM                                       Straydogger
# 8     A1C0O09LOLVI39                                           Michael
# 9      AKSFZ4G1AXYFC                                      C.E. "Frank"
# 10    A1GMWTGXW682GB                                          MetalFan
# 11     A3E0CF25A7LD2                                            WBowie
# 12     A67OJZLHBBUQ9                  Charles F. Marks "charlie marks"
# 13    A2W3CLAYZLDPTV                         Amazon Customer "=Chris="
# 14     AXP9CF1UTFRSU                                              tada
# 15    A2FZ4Z0UFA1OR8                                               Pat
# 16    A14Z9LAETO21KL                                         Gutjammer
# 17    A3DWQW2L39RB1S                                          S. Dawdy
# 18    A396ELNTQDFYPO                                         Mark King
# 19    A17CU1D2CWXOHB                                              Rick
# 20    A27DR1VO079F1V                                         Dan Edman
# 21    A2074KEJGRYJV4                                            hcross
# 22     AU9BPT3Y3K6J4                                       G. L. Beebe
# 23    A3UD50M7M72150                                      synthezatory
# 24    A1L7M2JXN4EZCR                                           David G
# 25    A3LNNEYLGGCO25                                            Hans R
# 26    A3VPISTBNS66C5                                          k2review
# 6145          130.0      192.0
# 6146         1215.0      192.0
# 6147          471.0      192.0
# 6148          700.0      192.0
# 6149            6.0      192.0
# 6150           12.0      192.0
#
# [6151 rows x 11 columns]

# %%
# TODO: Replace <FILL IN> with appropriate code
# This step is broken in ML Pipelines: https://issues.apache.org/jira/browse/SPARK-14489
from pyspark.ml.recommendation import ALS

# Let's initialize our ALS learner
als = ALS()

# Now we set the parameters for the method
als.setMaxIter(5)\
    .setSeed(seed)\
    .setRegParam(0.1)\
    .setUserCol('reviewerIndex')\
    .setItemCol('asinIndex')\
    .setRatingCol('overall')
    
# Now let's compute an evaluation metric for our test dataset
from pyspark.ml.evaluation import RegressionEvaluator

# Create an RMSE evaluator using the label and predicted columns
reg_eval = RegressionEvaluator(predictionCol="prediction", labelCol="overall", metricName="rmse")

tolerance = 0.03
ranks = [20, 24, 28]
errors = [0, 0, 0]
models = [0, 0, 0]
err = 0
min_error = float('inf')
best_rank = -1
for rank in ranks:
    # Set the rank here:
    als.setRank(rank)
    # Create the model with these parameters.
    model = als.fit(training_df)
    # Run the model to create a prediction. Predict against the validation_df.
    predict_df = model.transform(validation_df)
    
    # Remove NaN values from prediction (due to SPARK-14489)
    predicted_ratings_df = predict_df.filter(predict_df.prediction != float('nan'))

    # Run the previously created RMSE evaluator, reg_eval, on the predicted_ratings_df DataFrame
    error = reg_eval.evaluate(predicted_ratings_df)
    errors[err] = error
    models[err] = model
    print 'For rank %s the RMSE is %s' % (rank, error)
    if error < min_error:
        min_error = error
        best_rank = err
    err += 1

als.setRank(ranks[best_rank])
print 'The best model was trained with rank %s' % ranks[best_rank]
my_model = models[best_rank]
# Out:
# For rank 20 the RMSE is 2.18499637444
# For rank 24 the RMSE is 1.91118127249
# For rank 28 the RMSE is 1.9408043433
# The best model was trained with rank 24

# %%
# TODO: Replace <FILL_IN> with the appropriate code
# In ML Pipelines, this next step has a bug that produces unwanted NaN values. We
# have to filter them out. See https://issues.apache.org/jira/browse/SPARK-14489
predict_df = my_model.transform(test_df)

# Remove NaN values from prediction (due to SPARK-14489)
predicted_test_df = predict_df.filter(predict_df.prediction != float('nan'))

# Run the previously created RMSE evaluator, reg_eval, on the predicted_test_df DataFrame
test_RMSE = reg_eval.evaluate(predicted_test_df)

print('The model had a RMSE on the test set of {0}'.format(test_RMSE))
# Out:
# The model had a RMSE on the test set of 1.98658845486

# %%
# TODO: Replace <FILL_IN> with the appropriate code.
# Compute the average rating
import pyspark.sql.functions as F

avg_rating_df = training_df.groupBy().avg('overall')

# Extract the average rating value. (This is row 0, column 0.)
training_avg_rating = avg_rating_df.collect()[0][0]

print('The average rating for movies in the training set is {0}'.format(training_avg_rating))

# Add a column with the average rating
test_for_avg_df = test_df.withColumn('prediction', F.lit(training_avg_rating))

# Run the previously created RMSE evaluator, reg_eval, on the test_for_avg_df DataFrame
test_avg_RMSE = reg_eval.evaluate(test_for_avg_df)

print("The RMSE on the average set is {0}".format(test_avg_RMSE))
# Out:
# The average rating for movies in the training set is 4.4999187124
# The RMSE on the average set is 0.894400260161
